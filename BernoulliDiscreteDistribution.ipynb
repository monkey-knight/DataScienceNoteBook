# %% [markdown]
# # 一、伯努利离散分布

# %%
from scipy.stats import bernoulli

p = 0.5
mean, var, skew, kurtosis = bernoulli.stats(p, moments="mvsk")
print("平均值：", mean, "方差：", var, "偏度：", skew, "峰度：", kurtosis)
# Out:
# 平均值： 0.5 方差： 0.25 偏度： 0.0 峰度： -2.0
